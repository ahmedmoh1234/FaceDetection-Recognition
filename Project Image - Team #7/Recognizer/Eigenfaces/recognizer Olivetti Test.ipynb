# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import fetch_lfw_people
from sklearn.datasets import fetch_olivetti_faces
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import random
import cv2
from skimage.color import rgb2gray

# %%
path = 'D:\Senior II\Image Processing\Project\Datasets\Olivietta Dataset'

# %%
# ---------------------------- LOAD OLIVIETTA DATASET ---------------------------- #

dataset = fetch_olivetti_faces(data_home=path, shuffle=True, random_state=47)
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to D:\Senior II\Image Processing\Project\Datasets\Olivietta Dataset

# %%
images = dataset.images
print('Images shape:',images.shape)

total_images, height, width = images.shape
print(f'Each image has size: {height} x {width}')

print(70* '-')

n_features = height*width
print(f'N^2 = n_features = h x w = {n_features}')

print(70* '-')

y = dataset.target
print('y has shape:', y.shape)

num_people = np.max(y) + 1
print('Number of people =', num_people)
# Out:
# Images shape: (400, 64, 64)
# Each image has size: 64 x 64
# ----------------------------------------------------------------------
# N^2 = n_features = h x w = 4096
# ----------------------------------------------------------------------
# y has shape: (400,)
# Number of people = 40

# %%
#----------------------- CREATE PEOPLE DICTIONARY -----------------------#

# Key: person ID
# Value: List of all person images indices
person_image_dict = dict()

for image_index in range(total_images):
    if (y[image_index] not in person_image_dict.keys()):
        person_image_dict[y[image_index]] = [image_index]
    else:
        person_image_dict[y[image_index]].append(image_index)

# %%
train_images = []
test_images = []
y_train = []
y_test = []

# guarantee that each person has at least 1 image in test set
for image_index_lst in person_image_dict.values():
    total_size = len(image_index_lst)
    size_train = int(0.8 * total_size)
    for index in range(len(image_index_lst)):
        image = images[image_index_lst[index]]
        label = y[image_index_lst[index]]
        if (index < size_train):
            train_images.append(image)
            y_train.append(label)
        else:
            test_images.append(image)
            y_test.append(label)
    

train_images = np.array(train_images)
test_images = np.array(test_images)
y_train = np.array(y_train)
y_test = np.array(y_test)

print('Train images shape:', train_images.shape)
print('Test images shape:', test_images.shape)

m = train_images.shape[0]
m_test = test_images.shape[0]
print(70* '-')
print('Number of train images:', m)
print('Number of test images:', m_test)
# Out:
# Train images shape: (320, 64, 64)
# Test images shape: (80, 64, 64)
# ----------------------------------------------------------------------
# Number of train images: 320
# Number of test images: 80

# %%
# ------------------ VIEW RANDOM IMAGE ------------------ #
index = int(random.random() * m)
index = 0
image = images[index,:,:]
# name = target_names[y[index]]

# print(name)
plt.imshow(image, cmap='gray')
plt.show()

# %%
# --------------------- GET FLATTEN IMAGES --------------------- #

# Flatten images array
# Each column is an image

# N^2 * M
flattened_images = train_images.reshape(m, -1).T

# N^2 * M_test
flattened_test_images = test_images.reshape(m_test, -1).T

print(f'Shape of training images after flattening: {flattened_images.shape}')
print(f'Shape of test images after flattening: {flattened_test_images.shape}')
# Out:
# Shape of training images after flattening: (4096, 320)
# Shape of test images after flattening: (4096, 80)

# %%
# ----------------- CALCULATE AVERAGE IMAGE ----------------- #

# In all corresponding pixels in all images, we calculate the average

# N^2 * 1
average_image = np.mean(flattened_images, axis = 1)[:,np.newaxis]

print(f'Average image has shape: {average_image.shape}')
plt.imshow(average_image.reshape(height,width), cmap='gray')
plt.show()
# Out:
# Average image has shape: (4096, 1)

# %%
#-------------------------------- GET DIFFERENCE IMAGES --------------------------------#

# Subtract the average image from all images
# This is done to remove the average face from all images
# N^2 * M
difference_images = flattened_images - average_image

print(f'Shape after subtracting average face: {difference_images.shape}')
# Out:
# Shape after subtracting average face: (4096, 320)

# %%
# --------------------- SHOW ONE DIFFERENCE IMAGE AND COMPARE TO ORIGINAL --------------------- #

index = int(random.random() * m)

plt.imshow(difference_images[:,index].reshape(height, width), cmap='gray')
plt.show()

# Print original image
plt.imshow(train_images[index,:,:], cmap='gray')
plt.show()

# %%
#--------------------- GET COVARIANCE MATRIX --------------------- #

# C = A * A^T where A = difference_images

# N^2 * M
A = difference_images

if (m > n_features):
    # N^2 * N^2
    covariance_matrix = np.matmul(difference_images, difference_images.T)
    print('Shape of covariance matrix = N^2 * N^2 = ', covariance_matrix.shape)
    
else:
    # M * M
    covariance_matrix = np.matmul(difference_images.T, difference_images)
    print('Shape of covariance matrix = M * M = ', covariance_matrix.shape)
# Out:
# Shape of covariance matrix = M * M =  (320, 320)

# %%
# --------------------------------- GET EIGENVALUES AND EIGENVECTORS --------------------------------- #
# M eigenvalues and M eigenvectors
# where M is the number of examples

eigenvalues, eigenvectors = np.linalg.eigh(covariance_matrix)
print('Shape of eigenvalues:', eigenvalues.shape)
print('Shape of eigenvectors before matrix multiplication:', eigenvectors.shape)

# Try to remove
eigenvectors = np.matmul(difference_images, eigenvectors)

print('Shape of eigenvectors after matrix multiplication:', eigenvectors.shape)
# Out:
# Shape of eigenvalues: (320,)
# Shape of eigenvectors before matrix multiplication: (320, 320)
# Shape of eigenvectors after matrix multiplication: (4096, 320)

# %%
# --------------------------------- NORMALIZE EIGENVECTORS --------------------------------- #

eigenvectors = eigenvectors / np.linalg.norm(eigenvectors, axis=0)

print('Shape of eigenvectors after normalization:', eigenvectors.shape)
# Out:
# Shape of eigenvectors after normalization: (4096, 320)

# %%
# ------------------------ SORT EIGENVECTORS ------------------------ #

# Get top K eigenvectors
indices_of_top_eigenvalues = np.argsort(-eigenvalues)
eigenvalues = eigenvalues[indices_of_top_eigenvalues]
eigenvectors = eigenvectors[:, indices_of_top_eigenvalues]

# %%
# --------------------------------- CALCULATE K --------------------------------- #

#Try to understand

#Calculate the number of components to preserve 95% of the variance
variance = 0.95
K = m
for ii, eigen_value_cumsum in enumerate(np.cumsum(eigenvalues) / np.sum(eigenvalues)):
    if eigen_value_cumsum > variance:
        K = ii
        break

print(f'Number of components to preserve {variance*100}% of the variance = {K}')
# Out:
# Number of components to preserve 95.0% of the variance = 109

# %%
# --------------------------------- SELECT K TOP EIGENVECTORS --------------------------------- #

# Select only K Eigenvectors
eigenvalues = eigenvalues[:K].copy()
eigenvectors = eigenvectors[:, :K].copy()

print('Shape of eigenvalues after selecting top K:', eigenvalues.shape)
# N^2 * K
print('Shape of eigenvectors after selecting top K:', eigenvectors.shape)
# Out:
# Shape of eigenvalues after selecting top K: (109,)
# Shape of eigenvectors after selecting top K: (4096, 109)

# %%
for i in range(min(K, 16)):
    plt.subplot(4, 4, i+1)
    plt.imshow(eigenvectors[:,i].reshape(height, width), cmap='gray')
    plt.title(f'Eigenface {i+1}')
    plt.axis('off')

# %%
# ------------------------ SHOW A RANDOM EIGENFACE ------------------------ #

# index = int(random.random() * m)
index = 10
plt.imshow(eigenvectors[:,index].reshape(height, width), cmap='gray')
plt.show()

# %%
# ------------------------ CALCULATE OMEGAS ------------------------ #

omegas = []
for image in difference_images.T:
    omegas.append(np.dot(image, eigenvectors))
omegas = np.array(omegas)
print('Shape of omegas:', omegas.shape)
# Out:
# Shape of omegas: (320, 109)

# %%
# ------------------------ SAVE OMEGAS TO DISK ------------------------ #

np.save('omegas.npy', omegas)

# %% [markdown]
# ## Testing

# %%
def single_test(test_image):
    min_distance = float('inf')
    nearest_person = -1

    omega_image = np.matmul((test_image - average_image).T, eigenvectors)


    for i in range(m):
        omega = omegas[i]
        distance = np.linalg.norm(omega_image - omega)
        if distance < min_distance:
            min_distance = distance
            nearest_person = i

    # print(f'Nearest person is {nearest_person} with distance {min_distance}')



    # print(min_distance)
    if (y_train[nearest_person] == y_test[index]):
        # print('Correct')
        #Show them next to each other
        test_figure = plt.subplot(1, 2, 1)
        test_figure.set_title('Test image')
        plt.imshow(test_image.reshape(height, width), cmap='gray', label = 'Test image')
        true_figure = plt.subplot(1, 2, 2)
        true_figure.set_title('Nearest person')
        plt.imshow(train_images[nearest_person,:,:], cmap='gray', label='Nearest person')
        plt.show()
    else:
        #Show test image
        # print('Incorrect')
        test_figure = plt.subplot(1, 2, 1)
        test_figure.set_title('Test image')
        plt.imshow(test_image.reshape(height, width), cmap='gray', label = 'Test image')
        true_figure = plt.subplot(1, 2, 2)
        true_figure.set_title('Nearest person')
        plt.imshow(train_images[nearest_person,:,:], cmap='gray', label='Nearest person')
        plt.show()

# %%
# -------------------------------------- TESTING SINGLE IMAGE -------------------------------------- #

# index = int(random.random() * test_images.shape[0])
# index = 5
# test_image = flattened_test_images[:,index, np.newaxis]
# N^2 * 1
# print(f'Test image has shape: {test_image.shape}')

test_image = plt.imread('testImg2.jpg')
test_image = plt.imread('olivetti_faces_10.jpg')
if (len(test_image.shape) > 2):
    test_image = rgb2gray(test_image)
test_image = cv2.resize(test_image, (64,64))
if (np.max(test_image) > 1):
    test_image = test_image / 255.0
test_image = test_image.reshape((width*height, 1))
single_test(test_image)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Work\CCE\Year 4 - Senior 2\Semester 1\Senior-2-Semester-1\Image Processing\Project\FaceDetection-Recognition\Recognizer\Eigenfaces\Previous Recognizer Trials\recognizer.ipynb Cell 24 in <cell line: 9>()
#       <a href='vscode-notebook-cell:/d%3A/Work/CCE/Year%204%20-%20Senior%202/Semester%201/Senior-2-Semester-1/Image%20Processing/Project/FaceDetection-Recognition/Recognizer/Eigenfaces/Previous%20Recognizer%20Trials/recognizer.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> # -------------------------------------- TESTING SINGLE IMAGE -------------------------------------- #
#       <a href='vscode-notebook-cell:/d%3A/Work/CCE/Year%204%20-%20Senior%202/Semester%201/Senior-2-Semester-1/Image%20Processing/Project/FaceDetection-Recognition/Recognizer/Eigenfaces/Previous%20Recognizer%20Trials/recognizer.ipynb#X32sZmlsZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell:/d%3A/Work/CCE/Year%204%20-%20Senior%202/Semester%201/Senior-2-Semester-1/Image%20Processing/Project/FaceDetection-Recognition/Recognizer/Eigenfaces/Previous%20Recognizer%20Trials/recognizer.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> # index = int(random.random() * test_images.shape[0])
#    (...)
#       <a href='vscode-notebook-cell:/d%3A/Work/CCE/Year%204%20-%20Senior%202/Semester%201/Senior-2-Semester-1/Image%20Processing/Project/FaceDetection-Recognition/Recognizer/Eigenfaces/Previous%20Recognizer%20Trials/recognizer.ipynb#X32sZmlsZQ%3D%3D?line=5'>6</a> # N^2 * 1
#       <a href='vscode-notebook-cell:/d%3A/Work/CCE/Year%204%20-%20Senior%202/Semester%201/Senior-2-Semester-1/Image%20Processing/Project/FaceDetection-Recognition/Recognizer/Eigenfaces/Previous%20Recognizer%20Trials/recognizer.ipynb#X32sZmlsZQ%3D%3D?line=6'>7</a> # print(f'Test image has shape: {test_image.shape}')
# ----> <a href='vscode-notebook-cell:/d%3A/Work/CCE/Year%204%20-%20Senior%202/Semester%201/Senior-2-Semester-1/Image%20Processing/Project/FaceDetection-Recognition/Recognizer/Eigenfaces/Previous%20Recognizer%20Trials/recognizer.ipynb#X32sZmlsZQ%3D%3D?line=8'>9</a> test_image = plt.imread('testImg2.jpg')
#      <a href='vscode-notebook-cell:/d%3A/Work/CCE/Year%204%20-%20Senior%202/Semester%201/Senior-2-Semester-1/Image%20Processing/Project/FaceDetection-Recognition/Recognizer/Eigenfaces/Previous%20Recognizer%20Trials/recognizer.ipynb#X32sZmlsZQ%3D%3D?line=9'>10</a> test_image = plt.imread('olivetti_faces_10.jpg')
#      <a href='vscode-notebook-cell:/d%3A/Work/CCE/Year%204%20-%20Senior%202/Semester%201/Senior-2-Semester-1/Image%20Processing/Project/FaceDetection-Recognition/Recognizer/Eigenfaces/Previous%20Recognizer%20Trials/recognizer.ipynb#X32sZmlsZQ%3D%3D?line=10'>11</a> if (len(test_image.shape) > 2):
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2123, in imread(fname, format)
#    2121 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2122 def imread(fname, format=None):
# -> 2123     return matplotlib.image.imread(fname, format)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py:1541, in imread(fname, format)
#    1534 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1535     # Pillow doesn't handle URLs directly.
#    1536     raise ValueError(
#    1537         "Please open the URL for reading and pass the "
#    1538         "result to Pillow, e.g. with "
#    1539         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1540         )
# -> 1541 with img_open(fname) as image:
#    1542     return (_pil_png_to_float_array(image)
#    1543             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#    1544             pil_to_array(image))
#
# File c:\ProgramData\Anaconda3\lib\site-packages\PIL\Image.py:2953, in open(fp, mode, formats)
#    2950     filename = fp
#    2952 if filename:
# -> 2953     fp = builtins.open(filename, "rb")
#    2954     exclusive_fp = True
#    2956 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testImg2.jpg'

# %%
# ---------------------------- TESTING ACCURACY ---------------------------- #
count_correct = 0
trials = 1000
max_correct_distances = float('-inf')
min_correct_distances = float('inf')
min_incorrect_distances = float('inf')
max_incorrect_distances = float('-inf')
sum_correct = 0
sum_incorrect = 0

for trial in range(trials):
    # Get test image index randomly
    index = int(random.random() * m_test)
    
    # Get image
    test_image = flattened_test_images[:,index, np.newaxis]


    min_distance = float('inf')
    nearest_person = -1


    omega_image = np.matmul((test_image - average_image).T, eigenvectors)

    for i in range(m):
        omega = omegas[i]
        distance = np.linalg.norm(omega_image - omega)
        if distance < min_distance:
            min_distance = distance
            nearest_person = i

    
    threshold = float('inf')
    if (min_distance < threshold):
        if(y_train[nearest_person] == y_test[index]):
            if (min_distance > max_correct_distances):
                max_correct_distances = min_distance
            if (min_distance < min_correct_distances):
                min_correct_distances = min_distance   
            sum_correct += min_distance
            count_correct += 1
        else:
            if (min_distance < min_incorrect_distances):
                min_incorrect_distances = min_distance
            if (min_distance > max_incorrect_distances):
                max_incorrect_distances = min_distance
            sum_incorrect += min_distance

print(f'Accuracy: {count_correct/trials*100}%')
# Out:
# Accuracy: 95.8%
